# %%
import netCDF4
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import warnings
import os
import fnmatch
import csv
# import logging

from datetime import datetime, date
from matplotlib import gridspec
from matplotlib import cm
from astropy.time import Time

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
def list_files_pattern(tdir, tpattern):
    """
    Looks for files matching pattern exist in directory,
    if not logs error and raises exception

    :param tdir: path to directory to be searched and tested
    :type tdir: str
    :param tpattern: file name pattern to be tested
    :type tpattern: str
    """
    if not os.path.isdir(tdir):
        print('Dir not found')
        return []

    matches = fnmatch.filter(os.listdir(tdir), tpattern)

    if matches:
        print('Dir found, and Pattern matches')
        return matches
    else:
        print('Dir found, and Pattern not match')
        return []

# %%
DIR = 'GlobTemp/1x1/test'
PATTERN = 'GT_SSD-L2-GOES__LST_2*.nc'
file_list = [os.path.join(DIR, f) for f in list_files_pattern(tdir=DIR, tpattern=PATTERN)]
print(file_list[:5])
# Out:
# Dir found, and Pattern matches
# ['GlobTemp/1x1/test\\GT_SSD-L2-GOES__LST_2-20150101_000000-LIPM-0.05X0.05-V1.0.nc', 'GlobTemp/1x1/test\\GT_SSD-L2-GOES__LST_2-20150101_010000-LIPM-0.05X0.05-V1.0.nc', 'GlobTemp/1x1/test\\GT_SSD-L2-GOES__LST_2-20150101_020000-LIPM-0.05X0.05-V1.0.nc', 'GlobTemp/1x1/test\\GT_SSD-L2-GOES__LST_2-20150101_030000-LIPM-0.05X0.05-V1.0.nc', 'GlobTemp/1x1/test\\GT_SSD-L2-GOES__LST_2-20150101_040000-LIPM-0.05X0.05-V1.0.nc']

# %%
LST_org = []
time_org = []
for filename in file_list:
    f = netCDF4.Dataset(filename, 'r')
    LST_org.append(f.variables['LST'][0,0])
    time_org.append(f.variables['jul_date'][0])

# %%
plt.plot(time_org,LST_org)

# %%
print(time_org[:5])
# Out:
# [masked_array(data=2457023.5,
#              mask=False,
#        fill_value=1e+20), masked_array(data=2457023.54166667,
#              mask=False,
#        fill_value=1e+20), masked_array(data=2457023.58333333,
#              mask=False,
#        fill_value=1e+20), masked_array(data=2457023.625,
#              mask=False,
#        fill_value=1e+20), masked_array(data=2457023.66666667,
#              mask=False,
#        fill_value=1e+20)]

# %%
print(LST_org[:100])
# Out:
# [masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, 294.94998, masked, masked, 301.50998, masked, masked, 295.44998, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, 292.32, masked, 292.47, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, 297.69998, 299.78998, masked, 296.47998, masked, masked, masked, 289.53998, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, 295.57, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, masked, 286.41998, 294.28, masked, 297.1, 289.66998, 293.75, masked, masked, masked]

# %%
# t = Time(jul_date,format='jd')
# t.datetime64
time = [Time(i,format='jd').datetime for i in time_org]

# %%
plt.plot(time,LST_org)

# %%
np.savez('LST_GEOS.npz',time = time,LST = LST_org)

# %%
time_list = [datetime.strftime(i,format = '%Y%m%d%H%M') for i in time]
print(time_list[:5])
# Out:
# ['201501010000', '201501010059', '201501010200', '201501010300', '201501010359']

# %%
np.savetxt("LST_GEOS_v3.csv", np.column_stack((time_list, LST_org)), delimiter=",", fmt='%s', header="Time,LST(K)")

# %%
FILE = 'GlobTemp/1x1/test/GT_SSD-L2-GOES__LST_2-20150101_000000-LIPM-0.05X0.05-V1.0.nc'
f = netCDF4.Dataset(FILE, 'r')
print(f)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     title: Land Surface Temperature from Geostationary Operational Environmental Satellite
#     summary: This file contains land surface temperature (LST) data in a harmonised format from operational Geostationary Operational Environmental Satellite (GOES) Level-2 observations. By using these data, you agree to cite the papers given in the references metadata field in any publications derived from them
#     institution: IPMA
#     history: Wed Sep 18 22:58:30 2019: ncks -d nj,1652,1652 -d ni,1916,1916 -O /mount/dmz28/www/globtemp/data/ftp/DATA/GOES/2015/01/GT_SSD-L2-GOES__LST_2-20150101_000000-LIPM-0.05X0.05-V1.0.nc GT_SSD-L2-GOES__LST_2-20150101_000000-LIPM-0.05X0.05-V1.0.nc
# Created using software developed at IPMA
#     comment: These data were reformatted using software developped by IPMA
#     license: Data use is free and open
#     id: GT_SSD-L2-GOES__LST_2
#     date_created: 07-10-2016 17:45:30Z+0000
#     product_version: 1.0
#     netcdf_version_id: 4.3.1.1 of Apr  4 2014 18:01:15 $
#     spatial_resolution: 0.05X0.05
#     start_time: 2014-12-31 23:45:00Z
#     time_coverage_start: 2014-12-31 23:45:00Z
#     stop_time: 2015-01-01 00:11:00Z
#     time_coverage_end: 2015-01-01 00:11:00Z
#     northernmost_latitude: 80.0
#     southernmost_latitude: -80.0
#     easternmost_longitude: 6.0
#     westernmost_longitude: -156.0
#     platform: GOES13
#     sensor: GOES Imager
#     processing_level: L2
#     keywords: Earth Science, Land Surface, Land Temperature, Land Surface Temperature
#     keywords_vocabulary: NASA Global change Master Directory (GCMD) Science Keywords
#     geospatial_lat_units: degrees_north
#     geospatial_lat_resolution: 0.05
#     geospatial_lon_units: degrees_east
#     geospatial_lon_resolution: 0.05
#     creator_name: Isabel Trigo
#     creator_email: isabel.trigo@ipma.pt
#     creator_url: http://www.globtemperature.info/
#     references: Copernicus Global Land
#     source:
#     acknowledgment: Development of the data was funded by ESA and NCEO
#     NCO: "4.5.2"
#     dimensions(sizes): nj(1), ni(1), time(1)
#     variables(dimensions): int16 LST(nj,ni), int16 LST_uncertainty(nj,ni), int16 QC(nj,ni), int16 dtime(nj,ni), float64 jul_date(time), float32 lat(nj,ni), float32 lon(nj,ni), int16 sataz(nj,ni), int16 satze(nj,ni)
#     groups:

# %%
# print(f.variables['LST'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int16 LST(nj, ni)
#     _FillValue: -8000
#     long_name: land surface temperature
#     standard_name: surface_temperature
#     units: K
#     valid_min: -8000
#     valid_max: 7000
#     coordinates: lat lon
#     comment: GOES pixel land surface temperature product
#     scale_factor: 0.01
#     add_offset: 273.15
# unlimited dimensions:
# current shape = (11, 11)
# filling on

# %%
print(f.variables['LST'].shape)
# Out:
# (1, 1)

# %%
print(f.variables['lat'][0,0])
# Out:
# -2.5999985

# %%
print(f.variables['lon'][0,0])
# Out:
# -60.199997

# %%
print(f.variables['LST'][0,0])
# Out:
# --

# %%
# scale_factor = 0.01
# add_offset = 273.15

# %%
# print(f.variables['LST'].shape)
# Out:
# (11, 11)

# %%
# print(f.variables['lat'][:5,:5])
# Out:
# [[-2.5       -2.5       -2.5       -2.5       -2.5      ]
#  [-2.550003  -2.550003  -2.550003  -2.550003  -2.550003 ]
#  [-2.5999985 -2.5999985 -2.5999985 -2.5999985 -2.5999985]
#  [-2.6500015 -2.6500015 -2.6500015 -2.6500015 -2.6500015]
#  [-2.7000046 -2.7000046 -2.7000046 -2.7000046 -2.7000046]]

# %%
# print(f.variables['lon'][:5,:10])
# Out:
# [[-60.5      -60.449997 -60.4      -60.35     -60.299995 -60.25
#   -60.199997 -60.15     -60.1      -60.049995]
#  [-60.5      -60.449997 -60.4      -60.35     -60.299995 -60.25
#   -60.199997 -60.15     -60.1      -60.049995]
#  [-60.5      -60.449997 -60.4      -60.35     -60.299995 -60.25
#   -60.199997 -60.15     -60.1      -60.049995]
#  [-60.5      -60.449997 -60.4      -60.35     -60.299995 -60.25
#   -60.199997 -60.15     -60.1      -60.049995]
#  [-60.5      -60.449997 -60.4      -60.35     -60.299995 -60.25
#   -60.199997 -60.15     -60.1      -60.049995]]

# %%
# print(f.variables['LST'][2,6])
# Out:
# --

# %%
# print(f.variables['lat'][2,6])
# Out:
# -2.5999985

# %%
# print(f.variables['lon'][2,6])
# Out:
# -60.199997

# %%
# index at Manaus is [2,6] in the data

# %%
# LST_org = f.variables['LST']
# LST = [(i*scale_factor + add_offset) for i in LST_org]

# %%
# print(LST[5])
# Out:
# [-- -- -- -- -- -- -- -- -- -- --]

# %%
# print(np.mean(LST))
# Out:
# -8000.0

# %%
# print(f.variables['jul_date'])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 jul_date(time)
#     long_name: julian date
#     units: d
#     comment: reference time in julian days at start of orbit
# unlimited dimensions:
# current shape = (1,)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
# print(f.variables['jul_date'][0])
# Out:
# 2457143.5

# %%
# print(f.variables['dtime'][0,0])
# Out:
# -2.1000001

# %%
# from astropy.time import Time

# %%
# jul_date = f.variables['jul_date'][0]

# %%
# t = Time(jul_date,format='jd')
# t.datetime64
# Out:
# numpy.datetime64('2015-05-01T00:00:00.000000000')

# %%
# print(t)
# Out:
# 2457143.5

# %%
# print(t.datetime)
# Out:
# 2015-05-01 00:00:00
